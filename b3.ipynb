# %%
from PIL import Image
from imgtools import *
from IPython.display import display 

path = 'C:\\Users\\ADMIN\\Desktop\\TranTien\\ThiGiacMayTinh\\01\\1.jpg'

# %%
img = loadImg(path)

# %%
display(img)
print(img.size)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=218x231>
# (218, 231)

# %%
img.resize((436,462))
# Out:
# <PIL.Image.Image image mode=RGB size=436x462>

# %%
img.thumbnail((109,115))

# %%
newImg = img.resize((436,462))
newImg.save('C:\\Users\\ADMIN\\Desktop\\TranTien\\ThiGiacMayTinh\\01\\resize.jpg')

# %%
thumbnail = img.thumbnail((109, 115))

# %%
thumbnail.save('C:\\Users\\ADMIN\\Desktop\\TranTien\\ThiGiacMayTinh\\01\\thumbnail.jpg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 thumbnail.save('C:\\Users\\ADMIN\\Desktop\\TranTien\\ThiGiacMayTinh\\01\\thumbnail.jpg')
#
# AttributeError: 'NoneType' object has no attribute 'save'

# %%
from PIL import Image
from imgtools import *
from IPython.display import display
folder = 'C:\\Users\\ADMIN\\Desktop\\TranTien\\ThiGiacMayTinh\\01'
imgs = getImgs(folder)

# %%
for img in imgs:
    display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=218x231>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x275>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=218x231>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=218x231>

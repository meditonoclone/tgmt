# %%
import matplotlib as mpl
from imgtools import *
import matplotlib.pyplot as plt
from PIL import Image

# %%
my_path = 'C:\\Users\\ADMIN\\Desktop\\TranTien\\ThiGiacMayTinh\\01\\1.jpg'
img = loadImg(my_path)
plt.imshow(img)

# %%
x = [1, 2, 3, 4, 55,66]
y = [10, 16, 20, 30, 22, 2]
plt.plot(x, y)
plt.show()

# %%
x = [1, 2, 3, 4, 55,66]
y = [10, 16, 20, 30, 22, 2]
plt.plot(x, y, color='red')
plt.show()

# %%
import matplotlib.pyplot as p
x = [1, 2, 3, 4, 55,66]
y = [10, 16, 20, 30, 22, 2]
p.plot(x, y, color='green')
p.title('chart')
p.show()

# %%
x = [1, 2, 3, 4, 55,66]
y = [10, 16, 20, 30, 22, 2]
p.plot(x, y, color='green')
p.title('chart')
p.axis('off')
p.show()

# %%
img = loadImg(my_path)
img = img.resize((100, 100))
x = [1, 2, 3, 4, 55,66]
y = [10, 16, 20, 30, 22, 2]
p.imshow(img)
p.plot(x, y,'bo--')
p.title('chart')
p.axis('off')
p.show()
